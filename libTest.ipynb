# %%
# %run QuadrotorFlyModel.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# D:\tempYear\gradeFour\paperConstrainQuad\git\simulation\consQuadSim\QuadrotorFly\QuadrotorFlyModel.py in <module>
#      29 import enum
#      30 from enum import Enum
# ---> 31 from . import MemoryStore
#      32 from . import SensorImu
#      33 from . import SensorBase
#
# ImportError: attempted relative import with no known parent package

# %%
from . import SensorImu
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ebb251d632c4> in <module>
# ----> 1 from . import SensorImu
#
# ImportError: attempted relative import with no known parent package
